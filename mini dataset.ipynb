# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/DeeptraceReward
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/DeeptraceReward

# %%
folder_path = '/content/drive/MyDrive/DeeptraceReward/fake_videos/'
items = os.listdir(folder_path)
print(f"Number of items in folder: {len(items)}")
# Out:
# Number of items in folder: 3320

# %%
# !unzip real_videos.zip -d real_videos_unzipped
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: real_videos_unzipped/real_videos/0_30_s_academic_v0_1_206-3AAdKl1UYZs-split_7.mp4
#   inflating: real_videos_unzipped/__MACOSX/real_videos/._0_30_s_academic_v0_1_206-3AAdKl1UYZs-split_7.mp4
#   inflating: real_videos_unzipped/real_videos/0_30_s_academic_v0_1_215-fJ47lmh3uiU-split_0.mp4
#   inflating: real_videos_unzipped/__MACOSX/real_videos/._0_30_s_academic_v0_1_215-fJ47lmh3uiU-split_0.mp4
#   inflating: real_videos_unzipped/real_videos/0_30_s_academic_v0_1_P6P6L.mp4
#   inflating: real_videos_unzipped/__MACOSX/real_videos/._0_30_s_academic_v0_1_P6P6L.mp4
#   inflating: real_videos_unzipped/real_videos/0_30_s_academic_v0_1_v_vi8zTSA6bhY.mp4
#   inflating: real_videos_unzipped/__MACOSX/real_videos/._0_30_s_academic_v0_1_v_vi8zTSA6bhY.mp4
#   inflating: real_videos_unzipped/real_videos/0_30_s_academic_v0_1_416-4TjB1J4QoUQ-split_2.mp4
# ...

# %%
folder_path = '/content/drive/MyDrive/DeeptraceReward/real_videos_unzipped/real_videos'
items = os.listdir(folder_path)
print(f"Number of items in folder: {len(items)}")
# Out:
# Number of items in folder: 3318

# %%
real_mini_path = '/content/drive/MyDrive/DeeptraceReward/real_mini'
fake_mini_path = '/content/drive/MyDrive/DeeptraceReward/fake_mini'

real_path = '/content/drive/MyDrive/DeeptraceReward/real_videos_unzipped/real_videos'
real_items = os.listdir(real_path)

fake_path = '/content/drive/MyDrive/DeeptraceReward/fake_videos'
fake_items = os.listdir(fake_path)

# %cd /content/drive/MyDrive/DeeptraceReward/real_videos_unzipped/real_videos/
length = len(real_items)
for index, video in enumerate(real_items):
  if index % 16 == 0:
    # !cp "$video" /content/drive/MyDrive/DeeptraceReward/real_mini/

# %cd /content/drive/MyDrive/DeeptraceReward/fake_videos/
length = len(fake_items)
for index, video in enumerate(fake_items):
  if index % 16 == 0:
    # !cp "$video" /content/drive/MyDrive/DeeptraceReward/fake_mini/
# Out:
# /content/drive/MyDrive/DeeptraceReward/real_videos_unzipped/real_videos
# /content/drive/MyDrive/DeeptraceReward/fake_videos

# %%
folder_path = '/content/drive/MyDrive/DeeptraceReward/real_mini'
items = os.listdir(folder_path)
print(f"Number of items in folder: {len(items)}")
# Out:
# Number of items in folder: 208

# %%
folder_path = '/content/drive/MyDrive/DeeptraceReward/fake_mini'
items = os.listdir(folder_path)
print(f"Number of items in folder: {len(items)}")
# Out:
# Number of items in folder: 208
